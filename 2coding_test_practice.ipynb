# %% [markdown]
# ミニ問題1（重複チェック）
# 整数のリストAがある。同じ値が2回以上出るならTrue、全部違うならFalseを返す関数を書いてください。
# 例：[1,2,3] -> False、[1,2,1] -> True

# %%
def solution(A):
  count = 0
    for x in A:
        if x == 2:
            count += 1
        
    return count

# %% [markdown]
# A = [1,2,2,3,2]
# 「2が何回出たか」ではなく、
#
# 👉 「一番多く出た数字を返す」

# %%
def counter(A):
    counts = {}

    for x in A:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1

    max_count = 0
    maxnum = None

    for x in counts:
        if  counts[x] > max_count:
            max_count = counts[x]
            maxnum = counts
    return maxnum
